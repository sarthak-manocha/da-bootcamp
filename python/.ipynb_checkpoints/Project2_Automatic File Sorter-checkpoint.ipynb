# %% [markdown]
# # **Automatic File Sorter in File Explorer**

# %%
import os, shutil

# %%
path = r"C:/Users/Sarthak Manocha/Projects/da-bootcamp/python/sample files/"
print("Files in this directory: ", path, " will be sorted")
# Out:
# Files in this directory:  C:/Users/Sarthak Manocha/Projects/da-bootcamp/python/sample files/  will be sorted

# %%
file_name = os.listdir(path)
print(file_name)
# Out:
# ['cat_kisses.gif', 'cool_cat.jpg', 'demo file.txt', 'masked.jpg', 'Sample Resume 2.docx', 'Sample Resume.docx', 'sun_planetary.gif', 'vgsales.csv']

# %%
folder_names = ['csv files', 'image files', 'text files']

for loop in range(len(folder_names)):
    if not os.path.exists(path + folder_names[loop]):
        print(path + folder_names[loop])
        os.makedirs(path + folder_names[loop])
# Out:
# C:/Users/Sarthak Manocha/Projects/da-bootcamp/python/sample files/csv files
# C:/Users/Sarthak Manocha/Projects/da-bootcamp/python/sample files/image files
# C:/Users/Sarthak Manocha/Projects/da-bootcamp/python/sample files/text files

# %%
for file in file_name:
    if ".csv" in file and not os.path.exists(path + "csv files/" + file):
        shutil.move(path + file, path + "csv files/" + file)
    elif ".jpg" in file and not os.path.exists(path + "image files/" + file):
        shutil.move(path + file, path + "image files/" + file)
    elif ".txt" in file and not os.path.exists(path + "text files/" + file):
        shutil.move(path + file, path + "text files/" + file)
    else:
        print("Error with file: " + path + file)
# Out:
# Error with file: C:/Users/Sarthak Manocha/Projects/da-bootcamp/python/sample files/cat_kisses.gif
# Error with file: C:/Users/Sarthak Manocha/Projects/da-bootcamp/python/sample files/Sample Resume 2.docx
# Error with file: C:/Users/Sarthak Manocha/Projects/da-bootcamp/python/sample files/Sample Resume.docx
# Error with file: C:/Users/Sarthak Manocha/Projects/da-bootcamp/python/sample files/sun_planetary.gif
